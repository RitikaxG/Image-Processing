# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# [R,G,B]
#
# [255,0,0] - Red
#
# [0,255,0] - Blue
#
# [0,0,255] - Green

# %% [markdown]
# ### 1. Creating Red Image

# %%
arr = np.array([
               [[255,0,0],    [255,0,0],      [255,0,0]],
               [[255,0,0],    [255,0,0],      [255,0,0]],
               [[255,0,0],    [255,0,0],      [255,0,0]]
             ])
plt.imshow(arr)
cv.imwrite('Red.png',arr)
# Out:
# True

# %% [markdown]
# ### 2. Creating Blue Image

# %%
arr = np.array([
               [[0,255,0],    [0,255,0],      [0,255,0]],
               [[0,255,0],    [0,255,0],      [0,255,0]],
               [[0,255,0],    [0,255,0],      [0,255,0]]
             ])
plt.imshow(arr)
cv.imwrite('Green.png',arr)
# Out:
# True

# %% [markdown]
# ### 3. Creating Green Image

# %%
arr = np.array([
               [[0,0,255],  [0,0,255],    [0,0,255]],
               [[0,0,255],  [0,0,255],    [0,0,255]],
               [[0,0,255],  [0,0,255],    [0,0,255]]
             ])
plt.imshow(arr)
cv.imwrite('Blue.png',arr)
# Out:
# True

# %% [markdown]
# * When we are loading an image using opencv, rather than taking RGB it will convert it into BGR. Therefore, Blue and Red images are interchanged on exporting.

# %% [markdown]
# ### 4. Creating Red Green Blue Image Pattern

# %%
arr = np.array([
               [[255,0,0],  [255,0,0],    [255,0,0]],
               [[0,255,0],  [0,255,0],    [0,255,0]],
               [[0,0,255],  [0,0,255],    [0,0,255]]
             ])
plt.imshow(arr)
cv.imwrite('Blue.png',arr)
# Out:
# True

# %% [markdown]
# ### 5. Creating Different Shades of Red

# %%
arr = np.array([
               [[30,0,0],    [60,0,0],      [90,0,0]],
               [[120,0,0],   [150,0,0],    [180,0,0]],
               [[210,0,0],   [240,0,0],    [255,0,0]]
             ])
plt.imshow(arr)

# %% [markdown]
# ### Creating Different Shades of Green

# %%
arr = np.array([
               [[0,30,0],    [0,60,0],      [0,90,0]],
               [[0,120,0],    [0,150,0],      [0,180,0]],
               [[0,210,0],    [0,240,0],      [0,255,0]]
             ])
plt.imshow(arr)

# %% [markdown]
# ### Creating Different Shades of Blue

# %%
arr = np.array([
               [[0,0,30],  [0,0,60],    [0,0,90]],
               [[0,0,120],  [0,0,150],    [0,0,180]],
               [[0,0,210],  [0,0,240],    [0,0,255]]
             ])
plt.imshow(arr)

# %% [markdown]
# ### Merging all Images given above

# %%
arr = np.array([
               [[30,0,0],     [60,0,0],      [90,0,0]],
                [[0,30,0],    [0,60,0],      [0,90,0]],
                [[0,0,30],    [0,0,60],      [0,0,90]],
               [[0,120,0],    [0,150,0],     [0,180,0]],
                [[0,0,120],   [0,0,150],     [0,0,180]],
             ])
plt.imshow(arr)

# %%
arr = np.array([[[0,70,0],[0,150,0],[0,255,0]],
               [[70,0,0],[150,0,0],[255,0,0]],
               [[0,0,70],[0,0,150],[0,0,255]]])
plt.imshow(arr)

# %% [markdown]
# ### Creating Shades of Red- Dense

# %%
img = []
for i in range(256):
    t = []
    for j in range(256):
        t.append([i,0,0])
    img.append(t)
    
img = np.array(img)

# %%
plt.imshow(img)

# %% [markdown]
# ### Creating Shades of Green - Dense

# %%
img = []
for i in range(256):
    t = []
    for j in range(256):
        t.append([0,i,0])
    img.append(t)
    
img = np.array(img)
plt.imshow(img)

# %% [markdown]
# ### Creating shades of Blue - Dense

# %%
img = []
for i in range(256):
    t = []
    for j in range(256):
        t.append([0,0,i])
    img.append(t)
    
img = np.array(img)
plt.imshow(img)

# %% [markdown]
# ### Merging 3 Shades

# %%
img = []
# Red
for i in range(256):  # From black to red
    t = []
    for j in range(1536):
        t.append([i,0,0])
    img.append(t)
    
for i in range(256,0,-1):  # From red to black
    t = []
    for j in range(1536):
        t.append([i,0,0])
    img.append(t)

# Green
for i in range(256):  # From black to green
    t = []
    for j in range(1536):
        t.append([0,i,0])
    img.append(t)
    
for i in range(256,0,-1):  # From green to black
    t = []
    for j in range(1536):
        t.append([0,i,0])
    img.append(t)

# Blue
for i in range(256):  # From black to blue
    t = []
    for j in range(1536):
        t.append([0,0,i])
    img.append(t)
    
for i in range(256,0,-1):  # From blue to black
    t = []
    for j in range(1536):
        t.append([0,0,i])
    img.append(t)
    
img = np.array(img)
plt.imshow(img)

# (256+256)*3 {Black to red & red to black}* For 3 colors
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cv.imwrite('Transition.jpg',img)
# Out:
# True

# %% [markdown]
# ### Creating Custom Colours

# %%
arr = np.array([
               [[249,220,104],   [55,126,34],      [90,0,0]],
               [[139,206,247],   [239,134,59],    [180,0,0]],
               [[113,117,229],   [240,0,0],    [255,0,0]]
             ])
plt.imshow(arr)

# %% [markdown]
# ### Create Dense Image of Particular Colour

# %%
img = []
# Red
for i in range(720):  # From black to red
    t = []
    for j in range(1080):
        t.append([239,134,59])
    img.append(t)
plt.imshow(img)

# %%
img = []
# Red
for i in range(720):  # From black to red
    t = []
    for j in range(1080):
        t.append([59,134,239])
    img.append(t)
plt.imshow(img)

# %% [markdown]
# * The red and blue channel will be interchanged on exporting the img using opencv
#
# RGB -> BGR
#
# BGR -> RGB
